# %% [markdown]
# <a href="https://colab.research.google.com/github/dalinbrea/tareas/blob/main/Ejercicio1m4ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Datos proporcionados
metros = np.array([1, 2, 3, 4, 5, 6, 7, 8])
niños = np.array([2, 6, 10, 5, 10, 3, 2, 2])

# a) Tabla de Frecuencia
df = pd.DataFrame({'Metros': metros, 'Niños': niños})

# Frecuencias absolutas
frecuencia_absoluta = df['Niños']

# Frecuencias relativas
frecuencia_relativa = df['Niños'] / df['Niños'].sum()

# Frecuencia acumulada
frecuencia_acumulada = frecuencia_absoluta.cumsum()

# Añadir las frecuencias al DataFrame
df['Frecuencia Absoluta'] = frecuencia_absoluta
df['Frecuencia Relativa'] = frecuencia_relativa
df['Frecuencia Acumulada'] = frecuencia_acumulada

print("Tabla de Frecuencia:")
print(df)

# Diagramas de barras
plt.figure(figsize=(14, 7))

# Diagrama de Barras para las frecuencias absolutas
plt.subplot(1, 3, 1)
plt.bar(metros, frecuencia_absoluta, color='skyblue')
plt.xlabel('Metros')
plt.ylabel('Frecuencia Absoluta')
plt.title('Frecuencia Absoluta')

# Diagrama de Barras para las frecuencias relativas
plt.subplot(1, 3, 2)
plt.bar(metros, frecuencia_relativa, color='lightgreen')
plt.xlabel('Metros')
plt.ylabel('Frecuencia Relativa')
plt.title('Frecuencia Relativa')

# Diagrama de Barras para las frecuencias acumuladas
plt.subplot(1, 3, 3)
plt.bar(metros, frecuencia_acumulada, color='lightcoral')
plt.xlabel('Metros')
plt.ylabel('Frecuencia Acumulada')
plt.title('Frecuencia Acumulada')

plt.tight_layout()
plt.show()

# b) Mediana, media aritmética, moda y cuartiles
# Expandir los datos para calcular estadísticas
datos_expandido = np.repeat(metros, niños)

media = np.mean(datos_expandido)
mediana = np.median(datos_expandido)
moda = stats.mode(datos_expandido)[0][0]
cuartiles = np.percentile(datos_expandido, [25, 50, 75])

print(f"Media Aritmética: {media}")
print(f"Mediana: {mediana}")
print(f"Moda: {moda}")
print(f"Cuartiles: {cuartiles}")

# c) Varianza y desviación estándar
varianza = np.var(datos_expandido, ddof=1)
desviacion_estandar = np.std(datos_expandido, ddof=1)

print(f"Varianza: {varianza}")
print(f"Desviación Estándar: {desviacion_estandar}")

# d) ¿Entre qué dos valores se encuentra, como mínimo, el 75% de las observaciones?
# Usando el teorema de Chebyshev: al menos el 75% de los datos están dentro de k = 2 desviaciones estándar de la media
k = 2
limite_inferior = media - k * desviacion_estandar
limite_superior = media + k * desviacion_estandar

print(f"El 75% de las observaciones se encuentra, como mínimo, entre {limite_inferior} y {limite_superior}")
# Out:
# Tabla de Frecuencia:
#    Metros  Niños  Frecuencia Absoluta  Frecuencia Relativa  \
# 0       1      2                    2                0.050
# 1       2      6                    6                0.150
# 2       3     10                   10                0.250
# 3       4      5                    5                0.125
# 4       5     10                   10                0.250
# 5       6      3                    3                0.075
# 6       7      2                    2                0.050
# 7       8      2                    2                0.050
#
#    Frecuencia Acumulada
# 0                     2
# 1                     8
# 2                    18
# 3                    23
# 4                    33
# 5                    36
# 6                    38
# 7                    40
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ...
